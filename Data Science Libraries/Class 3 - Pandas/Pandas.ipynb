# %% [markdown]
# # Pandas

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[171], line 1
# ----> 1 data = pd.read_csv("https://github.com/datasciencedojo/datasets/blob/master/titanic.csv")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 a1
#
# NameError: name 'a1' is not defined

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.to_csv("titanic.csv")

# %%
pd.DataFrame([1,2,3],columns=["my first col"],index = ['row1','row2','row3'])
# Out:
#       my first col
# row1             1
# row2             2
# row3             3

# %%
pd.DataFrame({'col1':[1,2],'col2':[3,4]},index = ['r1','r2'],columns=['col2','col1'])
# Out:
#     col2  col1
# r1     3     1
# r2     4     2

# %%
import os
os.getcwd()
# Out:
# '/Users/admin/Github/fsds-genai-mar24/Data Science Libraries/Class 3 - Pandas'

# %%
titanic = pd.read_csv("data/titanic_data.csv")

# %%
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
titanic_from_json = pd.read_json("titanic_data.json")

# %%
titanic_cut = titanic.iloc[0:2]

# %%
titanic_cut.to_json("titanic_cut.json")

# %%
titanic_from_json
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
titanic.to_clipboard()

# %%
titanic.to_csv("titanic_pipe.csv",sep='|')

# %%
jsonData = {
    "page": 2,
    "per_page": 6,
    "total": 12,
    "total_pages": 2,
    "data": [
        {
            "id": 7,
            "email": "michael.lawson@reqres.in",
            "first_name": "Michael",
            "last_name": "Lawson",
            "avatar": "https://reqres.in/img/faces/7-image.jpg"
        },
        {
            "id": 11,
            "email": "george.edwards@reqres.in",
            "first_name": "George",
            "last_name": "Edwards",
            "avatar": "https://reqres.in/img/faces/11-image.jpg"
        },
        {
            "id": 12,
            "email": "rachel.howell@reqres.in",
            "first_name": "Rachel",
            "last_name": "Howell",
            "avatar": "https://reqres.in/img/faces/12-image.jpg"
        }
    ],
    "support": {
        "url": "https://reqres.in/#support-heading",
        "text": "To keep ReqRes free, contributions towards server costs are appreciated!"
    }
}

# %%
a= jsonData["data"]

# %%
a
# Out:
# [{'id': 7,
#   'email': 'michael.lawson@reqres.in',
#   'first_name': 'Michael',
#   'last_name': 'Lawson',
#   'avatar': 'https://reqres.in/img/faces/7-image.jpg'},
#  {'id': 11,
#   'email': 'george.edwards@reqres.in',
#   'first_name': 'George',
#   'last_name': 'Edwards',
#   'avatar': 'https://reqres.in/img/faces/11-image.jpg'},
#  {'id': 12,
#   'email': 'rachel.howell@reqres.in',
#   'first_name': 'Rachel',
#   'last_name': 'Howell',
#   'avatar': 'https://reqres.in/img/faces/12-image.jpg'}]

# %%
pd.DataFrame(a)
# Out:
#    id                     email first_name last_name  \
# 0   7  michael.lawson@reqres.in    Michael    Lawson
# 1  11  george.edwards@reqres.in     George   Edwards
# 2  12   rachel.howell@reqres.in     Rachel    Howell
#
#                                      avatar
# 0   https://reqres.in/img/faces/7-image.jpg
# 1  https://reqres.in/img/faces/11-image.jpg
# 2  https://reqres.in/img/faces/12-image.jpg

# %% [markdown]
# # Pandas Operation

# %%
titanic.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
titanic.tail()
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                          Name     Sex   Age  SibSp  Parch  \
# 886                     Montvila, Rev. Juozas    male  27.0      0      0
# 887              Graham, Miss. Margaret Edith  female  19.0      0      0
# 888  Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1      2
# 889                     Behr, Mr. Karl Howell    male  26.0      0      0
# 890                       Dooley, Mr. Patrick    male  32.0      0      0
#
#          Ticket   Fare Cabin Embarked
# 886      211536  13.00   NaN        S
# 887      112053  30.00   B42        S
# 888  W./C. 6607  23.45   NaN        S
# 889      111369  30.00  C148        C
# 890      370376   7.75   NaN        Q

# %% [markdown]
# # columns

# %%
titanic
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
titanic['New_column'] = np.random.random(891)

# %%
titanic
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
titanic.Age > 25
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
titanic['ageGreaterThan25'] = titanic.Age > 25

# %%
titanic
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
titanic.shape
# Out:
# (891, 15)

# %%
titanic['AgePlus50'] = titanic.Age + 50

# %%
titanic
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
del titanic['New_column']

# %%
titanic
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
titanic.pop('Unnamed: 0')
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 886    886
# 887    887
# 888    888
# 889    889
# 890    890
# Name: Unnamed: 0, Length: 891, dtype: int64

# %%
titanic.head(1)
# Out:
#    PassengerId  Survived  Pclass          NameOfPassenger   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked  ageGreaterThan25
# 0      0  A/5 21171  7.25   NaN        S             False

# %%
titanic.rename(columns={"Name":"NameOfPassenger"},inplace=True)

# %%
titanic.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                      NameOfPassenger     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  ageGreaterThan25
# 0      0  A/5 21171   7.2500   NaN        S             False
# 1      0   PC 17599  71.2833   C85        C              True

# %%
titanic.rename(columns={"Sex":"Gender"},inplace=True)

# %%
titanic.head(1)
# Out:
#    PassengerId  Survived  Pclass          NameOfPassenger Gender   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris   male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked  ageGreaterThan25
# 0      0  A/5 21171  7.25   NaN        S             False

# %%
titanic.insert(1,'random',np.random.random(891))

# %%
titanic
# Out:
#      PassengerId    random  Survived  Pclass  \
# 0              1  0.000665         0       3
# 1              2  0.405531         1       1
# 2              3  0.016471         1       3
# 3              4  0.334534         1       1
# 4              5  0.679444         0       3
# ..           ...       ...       ...     ...
# 886          887  0.207220         0       2
# 887          888  0.253535         1       1
# 888          889  0.393638         0       3
# 889          890  0.782608         1       1
# 890          891  0.590292         0       3
#
#                                        NameOfPassenger  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %% [markdown]
# # Indexing & SLicing

# %%
l1 = [1,2,3,4]

# %%
l1[0:5]
# Out:
# [1, 2, 3, 4]

# %%
titanic.head()
# Out:
#    PassengerId    random  Survived  Pclass  \
# 0            1  0.000665         0       3
# 1            2  0.405531         1       1
# 2            3  0.016471         1       3
# 3            4  0.334534         1       1
# 4            5  0.679444         0       3
#
#                                      NameOfPassenger  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  ageGreaterThan25
# 0      0         A/5 21171   7.2500   NaN        S             False
# 1      0          PC 17599  71.2833   C85        C              True
# ...

# %%
titanic[400:403] #slice wrt rows
# Out:
#      PassengerId    random  Survived  Pclass           NameOfPassenger  \
# 400          401  0.045043         1       3        Niskanen, Mr. Juha
# 401          402  0.307264         0       3           Adams, Mr. John
# 402          403  0.689371         0       3  Jussila, Miss. Mari Aina
#
#      Gender   Age  SibSp  Parch             Ticket   Fare Cabin Embarked  \
# 400    male  39.0      0      0  STON/O 2. 3101289  7.925   NaN        S
# 401    male  26.0      0      0             341826  8.050   NaN        S
# 402  female  21.0      1      0               4137  9.825   NaN        S
#
#      ageGreaterThan25
# 400              True
# 401              True
# 402             False

# %%
titanic[1:11:2,0:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:173, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(1, 11, 2), slice(0, 2, None))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[337], line 1
# ----> 1 titanic[1:11:2,0:2]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# ...

# %% [markdown]
# # iloc

# %%
titanic_3 = titanic.head(3)

# %%
titanic_3[0:2]
# Out:
#    PassengerId    random  Survived  Pclass  \
# 0            1  0.000665         0       3
# 1            2  0.405531         1       1
#
#                                      NameOfPassenger  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  ageGreaterThan25
# 0      0  A/5 21171   7.2500   NaN        S             False
# 1      0   PC 17599  71.2833   C85        C              True

# %%
titanic_3[0:3,0:2]
# Out:
#    PassengerId    random
# 0            1  0.000665
# 1            2  0.405531
# 2            3  0.016471

# %%
titanic_3.iloc[,0:4]
# Out:
# PassengerId           3
# random         0.016471
# Survived              1
# Pclass                3
# Name: 2, dtype: object

# %%
titanic_3.iloc[:,-3::]
# Out:
#   Cabin Embarked  ageGreaterThan25
# 0   NaN        S             False
# 1   C85        C              True
# 2   NaN        S              True

# %%
col_name = titanic_3.columns

# %%
col_name[-3::]
# Out:
# Index(['Cabin', 'Embarked', 'ageGreaterThan25'], dtype='object')

# %%
col_name[2:4]
# Out:
# Index(['Survived', 'Pclass'], dtype='object')

# %%
titanic_3.iloc[0:2,2:4]
# Out:
#    Survived  Pclass
# 0         0       3
# 1         1       1
